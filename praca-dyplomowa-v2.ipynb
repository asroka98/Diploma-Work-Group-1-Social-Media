# %%
import pandas as pd
import pyarrow
import openpyxl
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\karolina.koziol\Documents\studia\praca-dyplomowa\Mental_Health_and_Social_Media_Balance_Dataset_dirty.csv"
               ,sep=","
               )

# %%
df.head(30)
# Out:
#    User_ID         Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0     U001         NaN     ERR                3.100000                  7.0
# 1     U002   30.000000   Other                5.100000                  7.0
# 2     U003   23.000000     ERR                7.400000                  6.0
# 3     U004   36.000000  Female                5.700000                  7.0
# 4     U005   34.000000  Female                7.000000                  4.0
# 5     U006   38.000000    Male                6.600000                  5.0
# 6     U007   26.000000  Female                7.800000                  4.0
# 7     U008   26.000000  Female                7.400000                  5.0
# 8     U009   39.000000    Male                4.700000                  7.0
# 9     U010         NaN     ERR                6.600000                  6.0
# 10    U011   18.000000  Female                2.800000                  7.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    500 non-null    object
#  1   Age                        482 non-null    float64
#  2   Gender                     500 non-null    object
#  3   Daily_Screen_Time(hrs)     486 non-null    float64
#  4   Sleep_Quality(1-10)        490 non-null    float64
#  5   Stress_Level(1-10)         477 non-null    float64
#  6   Days_Without_Social_Media  483 non-null    float64
#  7   Exercise_Frequency(week)   484 non-null    float64
#  8   Social_Media_Platform      500 non-null    object
#  9   Happiness_Index(1-10)      473 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#               Age  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# count  482.000000              486.000000           490.000000
# mean    37.222146                6.138320             6.895598
# std     22.510519                3.454650             3.907355
# min     16.000000                1.000000             2.000000
# 25%     25.000000                4.300000             5.000000
# 50%     35.000000                5.700000             6.000000
# 75%     43.000000                6.900000             7.000000
# max    180.626294               29.345107            33.352217
#
#        Stress_Level(1-10)  Days_Without_Social_Media  \
# count          477.000000                 483.000000
# mean             7.363026                   3.549599
# std              4.019927                   2.579419
# min              2.000000                   0.000000
# 25%              6.000000                   2.000000
# 50%              7.000000                   3.000000
# ...

# %%
df.drop_duplicates(keep="first",inplace=True)
df
# Out:
#     User_ID   Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0      U001   NaN     ERR                     3.1                  7.0
# 1      U002  30.0   Other                     5.1                  7.0
# 2      U003  23.0     ERR                     7.4                  6.0
# 3      U004  36.0  Female                     5.7                  7.0
# 4      U005  34.0  Female                     7.0                  4.0
# ..      ...   ...     ...                     ...                  ...
# 495     ERR  23.0     ERR                     6.9                  5.0
# 496    U497  43.0  Female                     5.6                  7.0
# 497    U498  41.0    Male                     7.7                  5.0
# 498    U499  23.0    Male                     4.2                  9.0
# 499    U500  43.0  Female                     5.9                  5.0
#
#      Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      236
# Female    217
# ERR        25
# Other      22
# Name: count, dtype: int64

# %%
df['Sleep_Quality(1-10)'].value_counts()
# Out:
# Sleep_Quality(1-10)
# 6.000000     113
# 7.000000     110
# 5.000000      88
# 8.000000      64
# 4.000000      51
# 9.000000      32
# 3.000000       9
# 10.000000      6
# 2.000000       2
# 22.739574      1
# 16.486762      1
# 31.098236      1
# 27.659572      1
# 22.453227      1
# 27.161573      1
# 24.444454      1
# 29.165370      1
# 27.829321      1
# 28.778165      1
# 12.822720      1
# 28.341413      1
# 30.461302      1
# 33.352217      1
# 33.048958      1
# Name: count, dtype: int64

# %%
df['Days_Without_Social_Media'].value_counts()
# Out:
# Days_Without_Social_Media
# 3.000000     84
# 2.000000     79
# 4.000000     75
# 5.000000     72
# 1.000000     53
# 0.000000     45
# 6.000000     35
# 7.000000     14
# 11.831561     1
# 15.545850     1
# 14.922192     1
# 11.092814     1
# 12.114073     1
# 8.473052      1
# 12.291890     1
# 9.626726      1
# 7.528696      1
# 14.642574     1
# 9.923745      1
# 12.616104     1
# 12.506984     1
# 8.608089      1
# 7.126193      1
# 11.265042     1
# 10.781575     1
# 12.706946     1
# 9.291501      1
# 8.994814      1
# 7.405099      1
# 12.902618     1
# 9.000000      1
# 11.238624     1
# 10.993299     1
# 10.026054     1
# Name: count, dtype: int64

# %%
df['Exercise_Frequency(week)'].value_counts()
# Out:
# Exercise_Frequency(week)
# 2.000000     119
# 3.000000     109
# 1.000000      85
# 4.000000      68
# 0.000000      41
# 5.000000      34
# 6.000000       4
# 5.622212       1
# 9.059902       1
# 11.809694      1
# 6.449423       1
# 9.443727       1
# 6.817550       1
# 9.011844       1
# 6.459707       1
# 10.478078      1
# 9.583536       1
# 7.923380       1
# 8.816807       1
# 7.275924       1
# 7.936498       1
# 7.063421       1
# 5.573589       1
# 7.878397       1
# 11.345462      1
# 5.616623       1
# 5.766829       1
# 10.030890      1
# 11.946164      1
# 7.000000       1
# 5.265107       1
# Name: count, dtype: int64

# %%
df['Social_Media_Platform'].value_counts()
# Out:
# Social_Media_Platform
# TikTok         83
# X (Twitter)    83
# LinkedIn       80
# Facebook       76
# Instagram      73
# YouTube        68
# ERR            37
# Name: count, dtype: int64

# %%
df['Happiness_Index(1-10)'].value_counts()
# Out:
# Happiness_Index(1-10)
# 10.000000    148
# 8.000000     100
# 9.000000      85
# 7.000000      69
# 6.000000      34
# 5.000000      14
# 4.000000       6
# 23.012565      1
# 40.554534      1
# 40.456189      1
# 36.540281      1
# 22.383707      1
# 23.519798      1
# 19.532661      1
# 24.253221      1
# 34.417287      1
# 41.477006      1
# 32.899530      1
# 30.051538      1
# 27.671882      1
# 27.457855      1
# 40.359127      1
# 23.034413      1
# 38.928872      1
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 43.000000     21
# 48.000000     21
# 47.000000     20
# 41.000000     20
# 39.000000     18
# 31.000000     18
# 17.000000     17
# 27.000000     17
# 23.000000     17
# 34.000000     16
# 40.000000     16
# 38.000000     16
# 18.000000     15
# 37.000000     14
# 44.000000     14
# 16.000000     13
# 22.000000     13
# 32.000000     12
# 45.000000     12
# 26.000000     12
# 20.000000     12
# 36.000000     12
# 35.000000     12
# 19.000000     11
# 42.000000     11
# 21.000000     11
# 29.000000     10
# 30.000000     10
# 24.000000     10
# 33.000000      9
# 46.000000      9
# 28.000000      8
# 49.000000      8
# 25.000000      7
# 141.420044     1
# 128.962066     1
# 165.103665     1
# 162.462624     1
# 134.557153     1
# 159.561241     1
# 150.425237     1
# 142.056241     1
# 127.109131     1
# 158.042641     1
# 132.406668     1
# 112.414514     1
# 89.538699      1
# 111.330877     1
# 115.574836     1
# 70.411879      1
# 123.946695     1
# 180.626294     1
# ...

# %%
df["duplikaty"]=df.duplicated(keep="first")
df
# Out:
#     User_ID   Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0      U001   NaN     ERR                     3.1                  7.0
# 1      U002  30.0   Other                     5.1                  7.0
# 2      U003  23.0     ERR                     7.4                  6.0
# 3      U004  36.0  Female                     5.7                  7.0
# 4      U005  34.0  Female                     7.0                  4.0
# ..      ...   ...     ...                     ...                  ...
# 495     ERR  23.0     ERR                     6.9                  5.0
# 496    U497  43.0  Female                     5.6                  7.0
# 497    U498  41.0    Male                     7.7                  5.0
# 498    U499  23.0    Male                     4.2                  9.0
# 499    U500  43.0  Female                     5.9                  5.0
#
#      Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# ...

# %%
dfQ = df.copy()

#User_ID
#Age
dfQ['Gender'] = df['Gender'].replace('ERR', pd.NA)
dfQ.loc[dfQ['Daily_Screen_Time(hrs)'] > 24, 'Daily_Screen_Time(hrs)'] = pd.NA
dfQ.loc[dfQ['Sleep_Quality(1-10)'] > 10, 'Sleep_Quality(1-10)'] = pd.NA
dfQ.loc[dfQ['Stress_Level(1-10)'] > 10, 'Stress_Level(1-10)'] = pd.NA
#Days_Without_Social_Media
#Exercise_Frequency(week)
dfQ['Social_Media_Platform'] = df['Social_Media_Platform'].replace('ERR', pd.NA)
dfQ.loc[dfQ['Happiness_Index(1-10)'] > 10, 'Happiness_Index(1-10)'] = pd.NA

dfQ
# Out:
#     User_ID   Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0      U001   NaN    <NA>                     3.1                  7.0
# 1      U002  30.0   Other                     5.1                  7.0
# 2      U003  23.0    <NA>                     7.4                  6.0
# 3      U004  36.0  Female                     5.7                  7.0
# 4      U005  34.0  Female                     7.0                  4.0
# ..      ...   ...     ...                     ...                  ...
# 495     ERR  23.0    <NA>                     6.9                  5.0
# 496    U497  43.0  Female                     5.6                  7.0
# 497    U498  41.0    Male                     7.7                  5.0
# 498    U499  23.0    Male                     4.2                  9.0
# 499    U500  43.0  Female                     5.9                  5.0
#
#      Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# ...

# %%
dfQ.to_csv(r"C:\Users\karolina.koziol\Documents\studia\praca-dyplomowa\Mental_Health_and_Social_Media_Balance_Dataset_clean.csv")
